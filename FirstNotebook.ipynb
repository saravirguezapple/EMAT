# %% [markdown]
# # This is a header!

# %% [markdown]
# ## This is a subheader!

# %% [markdown]
# **This is bold text** *this is italic text*

# %% [markdown]
# ![Image 1](image1.jpg)

# %%
x=5

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print("hello world")
# Out:
# hello world

# %%
print("hi") #comment
# Out:
# hi

# %%
def addNumbers(a,b):
    result = a+b
    return result 
addNumbers(3,4)
# Out:
# 7
