# %% [markdown]
# # From the class Data in Emerging Media and Technology

# %% [markdown]
# ## I hope to gain a lot of knowledge about how different systems work

# %% [markdown]
# **And how we can make the best use of each one** *depending on the task we want to accomplish.*

# %% [markdown]
# x=9

# %%
for i in range(9):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %% [markdown]
# ![EMAT](emergingmedia.jpg)
